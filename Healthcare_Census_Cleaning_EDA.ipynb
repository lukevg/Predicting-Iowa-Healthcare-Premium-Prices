# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
insurance_df = pd.read_csv('2017_Iowa_ACA_Compliant_Premiums.csv')
insurance_df.head(2)
# Out:
#           Plan ID            Insurance Company               Plan Name  \
# 0  72160IA0180002               Wellmark, Inc.     SimplyBlue 5500 PPO
# 1  27651IA0060005  Gundersen Health Plan, Inc.  Bronze HSA $5750 - 20%
#
#      Rating Area  Age Metal Level Market Place  Non-Tobacco Premium  \
# 0  Rating Area 2   55      Bronze          Off               753.36
# 1  Rating Area 7   60      Bronze           On               863.59
#
#    Tobacco Premium                                           Counties  \
# 0           866.36      Dallas, Jasper, Madison, Marion, Polk, Warren
# 1           863.59  Allamakee, Bremer, Butler, Cerro Gordo, Chicka...
#
#   Rating Area Centroid  County Boundaries of Iowa  US Counties  \
# 0      (41.52, -93.54)                         64         1878
# 1      (43.08, -92.99)                         19         1781
#
#    Iowa Watersheds (HUC 10)  Iowa Watershed Sub-Basins (HUC 08)  \
# 0                       356                                  29
# 1                       194                                  15
#
#    Iowa ZIP Code Tabulation Areas  :@computed_region_4qgw_m3n5
# 0                             483                            2
# 1                             284                            7

# %%
insurance_df.columns
# Out:
# Index(['Plan ID', 'Insurance Company', 'Plan Name', 'Rating Area', 'Age',
#        'Metal Level', 'Market Place', 'Non-Tobacco Premium', 'Tobacco Premium',
#        'Counties', 'Rating Area Centroid', 'County Boundaries of Iowa',
#        'US Counties', 'Iowa Watersheds (HUC 10)',
#        'Iowa Watershed Sub-Basins (HUC 08)', 'Iowa ZIP Code Tabulation Areas',
#        ':@computed_region_4qgw_m3n5'],
#       dtype='object')

# %%
insurance_df.nunique()
# Out:
# Plan ID                                 116
# Insurance Company                         8
# Plan Name                               115
# Rating Area                               7
# Age                                      46
# Metal Level                               5
# Market Place                              2
# Non-Tobacco Premium                   10650
# Tobacco Premium                       10695
# Counties                                  7
# Rating Area Centroid                      7
# County Boundaries of Iowa                 7
# US Counties                               7
# Iowa Watersheds (HUC 10)                  7
# Iowa Watershed Sub-Basins (HUC 08)        7
# Iowa ZIP Code Tabulation Areas            7
# :@computed_region_4qgw_m3n5               7
# dtype: int64

# %% [markdown]
# Will delete columns with 100+ categorical values, as well as all but one column (Rating_Area) with 7 values, since those columns are perfectly multicollinear with Rating_Area and do not impact the dependent variable non-Tobacco Premium.

# %%
insurance_df = insurance_df.drop(columns=['Plan ID', 'Plan Name', 'Rating Area Centroid', 'County Boundaries of Iowa',
       'US Counties', 'Iowa Watersheds (HUC 10)',
       'Iowa Watershed Sub-Basins (HUC 08)', 'Iowa ZIP Code Tabulation Areas',
       ':@computed_region_4qgw_m3n5'])

# %%
insurance_df = insurance_df.rename(columns = {"Rating Area":"Rating_Area", "Insurance Company":"Insurance_Company", \
    "Metal Level": "Metal_Level", "Market Place": "Marketplace", "Non-Tobacco Premium": "Non_Tobacco_Premium", "Tobacco Premium": "Tobacco_Premium"})

# %%
insurance_df.head()
# Out:
#              Insurance_Company    Rating_Area  Age Metal_Level Marketplace  \
# 0               Wellmark, Inc.  Rating Area 2   55      Bronze         Off
# 1  Gundersen Health Plan, Inc.  Rating Area 7   60      Bronze          On
# 2        Freedom Life Ins. Co.  Rating Area 7   62      Bronze         Off
# 3  Gundersen Health Plan, Inc.  Rating Area 7   25        Gold          On
# 4        Freedom Life Ins. Co.  Rating Area 2   43      Bronze         Off
#
#    Non_Tobacco_Premium  Tobacco_Premium  \
# 0               753.36           866.36
# 1               863.59           863.59
# 2               961.57          1153.89
# 3               472.06           472.06
# 4               408.72           490.46
#
#                                             Counties
# 0      Dallas, Jasper, Madison, Marion, Polk, Warren
# 1  Allamakee, Bremer, Butler, Cerro Gordo, Chicka...
# 2  Allamakee, Bremer, Butler, Cerro Gordo, Chicka...
# 3  Allamakee, Bremer, Butler, Cerro Gordo, Chicka...
# 4      Dallas, Jasper, Madison, Marion, Polk, Warren

# %% [markdown]
# Wiil now separate the county values in the Rating_Area column into their own column County so that we can work with county level data.

# %%
#Making sure there is consistent count across rows so that we can work with the data
insurance_df.groupby(['Rating_Area', 'Counties']).count()
# Out:
#                                                                   Insurance_Company  \
# Rating_Area   Counties
# Rating Area 1 Boone, Calhoun, Carroll, Greene, Grundy, Hamilt...               2024
# Rating Area 2 Dallas, Jasper, Madison, Marion, Polk, Warren                    2300
# Rating Area 3 Buena Vista, Cherokee, Clay, Crawford, Dickinso...               2024
# Rating Area 4 Adair, Adams, Audubon, Cass, Clarke, Decatur, F...               2668
# Rating Area 5 Appanoose, Davis, Des Moines, Henry, Jefferson,...               2254
# Rating Area 6 Benton, Black Hawk, Buchanan, Cedar, Clayton, C...               3542
# Rating Area 7 Allamakee, Bremer, Butler, Cerro Gordo, Chickas...               2760
#
#                                                                    Age  \
# Rating_Area   Counties
# Rating Area 1 Boone, Calhoun, Carroll, Greene, Grundy, Hamilt...  2024
# Rating Area 2 Dallas, Jasper, Madison, Marion, Polk, Warren       2300
# Rating Area 3 Buena Vista, Cherokee, Clay, Crawford, Dickinso...  2024
# Rating Area 4 Adair, Adams, Audubon, Cass, Clarke, Decatur, F...  2668
# Rating Area 5 Appanoose, Davis, Des Moines, Henry, Jefferson,...  2254
# Rating Area 6 Benton, Black Hawk, Buchanan, Cedar, Clayton, C...  3542
# Rating Area 7 Allamakee, Bremer, Butler, Cerro Gordo, Chickas...  2760
#
#                                                                   Metal_Level  \
# Rating_Area   Counties
# Rating Area 1 Boone, Calhoun, Carroll, Greene, Grundy, Hamilt...         2024
# Rating Area 2 Dallas, Jasper, Madison, Marion, Polk, Warren              2300
# Rating Area 3 Buena Vista, Cherokee, Clay, Crawford, Dickinso...         2024
# Rating Area 4 Adair, Adams, Audubon, Cass, Clarke, Decatur, F...         2668
# Rating Area 5 Appanoose, Davis, Des Moines, Henry, Jefferson,...         2254
# Rating Area 6 Benton, Black Hawk, Buchanan, Cedar, Clayton, C...         3542
# Rating Area 7 Allamakee, Bremer, Butler, Cerro Gordo, Chickas...         2760
#
#                                                                   Marketplace  \
# Rating_Area   Counties
# Rating Area 1 Boone, Calhoun, Carroll, Greene, Grundy, Hamilt...         2024
# Rating Area 2 Dallas, Jasper, Madison, Marion, Polk, Warren              2300
# Rating Area 3 Buena Vista, Cherokee, Clay, Crawford, Dickinso...         2024
# Rating Area 4 Adair, Adams, Audubon, Cass, Clarke, Decatur, F...         2668
# Rating Area 5 Appanoose, Davis, Des Moines, Henry, Jefferson,...         2254
# Rating Area 6 Benton, Black Hawk, Buchanan, Cedar, Clayton, C...         3542
# Rating Area 7 Allamakee, Bremer, Butler, Cerro Gordo, Chickas...         2760
#
#                                                                   Non_Tobacco_Premium  \
# Rating_Area   Counties
# Rating Area 1 Boone, Calhoun, Carroll, Greene, Grundy, Hamilt...                 2024
# Rating Area 2 Dallas, Jasper, Madison, Marion, Polk, Warren                      2300
# Rating Area 3 Buena Vista, Cherokee, Clay, Crawford, Dickinso...                 2024
# Rating Area 4 Adair, Adams, Audubon, Cass, Clarke, Decatur, F...                 2668
# Rating Area 5 Appanoose, Davis, Des Moines, Henry, Jefferson,...                 2254
# Rating Area 6 Benton, Black Hawk, Buchanan, Cedar, Clayton, C...                 3542
# Rating Area 7 Allamakee, Bremer, Butler, Cerro Gordo, Chickas...                 2760
#
#                                                                   Tobacco_Premium
# Rating_Area   Counties
# Rating Area 1 Boone, Calhoun, Carroll, Greene, Grundy, Hamilt...             2024
# Rating Area 2 Dallas, Jasper, Madison, Marion, Polk, Warren                  2300
# Rating Area 3 Buena Vista, Cherokee, Clay, Crawford, Dickinso...             2024
# Rating Area 4 Adair, Adams, Audubon, Cass, Clarke, Decatur, F...             2668
# Rating Area 5 Appanoose, Davis, Des Moines, Henry, Jefferson,...             2254
# Rating Area 6 Benton, Black Hawk, Buchanan, Cedar, Clayton, C...             3542
# Rating Area 7 Allamakee, Bremer, Butler, Cerro Gordo, Chickas...             2760

# %%
insurance_df_by_rating_area = insurance_df.groupby('Rating_Area')
#insurance_df_by_rating_area = insurance_df.groupby(["Rating_Area", "Counties"])

# %%
#insurance_df_by_rating_area.head(5)

# %%
new_df = pd.DataFrame(insurance_df.Counties.str.split(',').tolist(), index=insurance_df.Rating_Area).stack()
#new_df

# %%
new_df = new_df.reset_index([0, 'Rating_Area'])

# %%
new_df.columns = ['Rating_Area', 'County']

# %%
new_df['n'] = 1

# %%
county_rating_area_df = new_df.groupby(["Rating_Area", "County"], as_index=False).count().drop('n', axis=1)

# %%
county_rating_area_df['County'] = county_rating_area_df['County'].str.replace(" ", "")
county_rating_area_df['County'] = county_rating_area_df['County'].str.replace("’", "")
county_rating_area_df.head(3)
# Out:
#      Rating_Area   County
# 0  Rating Area 1  Calhoun
# 1  Rating Area 1  Carroll
# 2  Rating Area 1   Greene

# %% [markdown]
# Webscraping below to get population data for each county to incorporate into model.

# %%
county_pop_url = ('https://en.wikipedia.org/wiki/List_of_counties_in_Iowa')
county_pop_table = pd.read_html(county_pop_url)  
county_pop_df = county_pop_table[1]
county_pop_df.head(3)
# Out:
#              County  FIPS code[10] County seat[4]  # Established[4][11]  \
# 0      Adair County              1     Greenfield  1       Jan 15, 1851
# 1      Adams County              3        Corning  2       Jan 15, 1851
# 2  Allamakee County              5         Waukon  3       Feb 20, 1847
#
#   Formed from[12]                                      Etymology[11]  Map #  \
# 0     Cass County                      John Adair, Kentucky Governor     69
# 1   Taylor County                           John Adams, US President     81
# 2  Clayton County  Disputed, possibly Allan Makee, early trader a...     11
#
#    Population[13]               Area[4]  Map
# 0            7682  569 sq mi(1,474 km2)  NaN
# 1            4029  424 sq mi(1,098 km2)  NaN
# 2           14330  640 sq mi(1,658 km2)  NaN

# %%
#Reading in  county level census data to incorporate a variety of economic and demographic data into predictive model
counties_df = pd.read_csv('ACS_17_5YR_DP03_with_ann.csv', header = 1)
counties_df.head(3)
# Out:
#                Id    Id2               Geography  \
# 0  0500000US19001  19001      Adair County, Iowa
# 1  0500000US19003  19003      Adams County, Iowa
# 2  0500000US19005  19005  Allamakee County, Iowa
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over  \
# 0                                               5810
# 1                                               3087
# 2                                              11106
#
#    Margin of Error; EMPLOYMENT STATUS - Population 16 years and over  \
# 0                                                 34
# 1                                                 24
# 2                                                 64
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over  \
# 0                                               5810
# 1                                               3087
# 2                                              11106
#
#   Percent Margin of Error; EMPLOYMENT STATUS - Population 16 years and over  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over - In labor force  \
# 0                                               3794
# 1                                               1875
# 2                                               7118
#
#    Margin of Error; EMPLOYMENT STATUS - Population 16 years and over - In labor force  \
# 0                                                 96
# 1                                                 86
# 2                                                188
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force  \
# 0                                               65.3
# 1                                               60.7
# 2                                               64.1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over  \
# 0                                                9.9
# 1                                                7.3
# 2                                                7.5
#
#    Percent Margin of Error; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over  \
# 0                                                2.8
# 1                                                2.9
# 2                                                2.4
#
#    Estimate; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - People in families  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
#
#    Margin of Error; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - People in families  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - People in families  \
# 0                                                5.4
# 1                                                5.8
# 2                                                8.8
#
#    Percent Margin of Error; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - People in families  \
# 0                                                2.1
# 1                                                2.5
# 2                                                2.3
#
#    Estimate; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - Unrelated individuals 15 years and over  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
#
#    Margin of Error; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - Unrelated individuals 15 years and over  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - Unrelated individuals 15 years and over  \
# 0                                               25.6
# 1                                               30.8
# 2                                               22.3
#
#    Percent Margin of Error; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - Unrelated individuals 15 years and over
# 0                                                4.4
# 1                                                5.7
# 2                                                3.9
#
# [3 rows x 551 columns]

# %% [markdown]
# #### Cannot use the webscraped population data from Wikipedia above since it is for total population, and all other data is for populations at least 16 year and over.

# %%
#FILTERING OUT UNNEEDED COLUMNS
counties_df = counties_df[counties_df.columns.drop(list(counties_df.filter(regex='Error')))]
counties_df = counties_df[counties_df.columns.drop(list(counties_df.filter(regex='OCCUPATION')))]
counties_df = counties_df[counties_df.columns.drop(list(counties_df.filter(regex='INDUSTRY')))]
counties_df = counties_df[counties_df.columns.drop(list(counties_df.filter(regex='CLASS OF WORKER')))]
counties_df = counties_df[counties_df.columns.drop(list(counties_df.filter(regex='Id')))]
counties_df = counties_df[counties_df.columns.drop(list(counties_df.filter(regex='Armed')))]
counties_df = counties_df.replace("(X)", np.NaN)
counties_df = counties_df.dropna(axis=1, how='all')

# %%
counties_df.shape
# Out:
# (99, 187)

# %%
counties_df.head()
# Out:
#                 Geography  \
# 0      Adair County, Iowa
# 1      Adams County, Iowa
# 2  Allamakee County, Iowa
# 3  Appanoose County, Iowa
# 4    Audubon County, Iowa
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over  \
# 0                                               5810
# 1                                               3087
# 2                                              11106
# 3                                              10061
# 4                                               4710
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over  \
# 0                                               5810
# 1                                               3087
# 2                                              11106
# 3                                              10061
# 4                                               4710
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over - In labor force  \
# 0                                               3794
# 1                                               1875
# 2                                               7118
# 3                                               5874
# 4                                               2972
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force  \
# 0                                               65.3
# 1                                               60.7
# 2                                               64.1
# 3                                               58.4
# 4                                               63.1
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force  \
# 0                                               3794
# 1                                               1875
# 2                                               7118
# 3                                               5874
# 4                                               2962
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force  \
# 0                                               65.3
# 1                                               60.7
# 2                                               64.1
# 3                                               58.4
# 4                                               62.9
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Employed  \
# 0                                               3680
# 1                                               1796
# 2                                               6881
# 3                                               5502
# 4                                               2882
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Employed  \
# 0                                               63.3
# 1                                               58.2
# 2                                               62.0
# 3                                               54.7
# 4                                               61.2
#
#    Estimate; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Unemployed  \
# 0                                                114
# 1                                                 79
# 2                                                237
# 3                                                372
# 4                                                 80
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people  \
# 0                                                9.5
# 1                                               11.2
# 2                                               11.4
# 3                                               17.1
# 4                                               11.1
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years  \
# 0                                               12.1
# 1                                                8.6
# 2                                               15.3
# 3                                               26.3
# 4                                               15.3
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years - Related children of the householder under 18 years  \
# 0                                               11.7
# 1                                                8.6
# 2                                               15.2
# 3                                               25.7
# 4                                               14.6
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years - Related children of the householder under 18 years - Related children of the householder under 5 years  \
# 0                                               24.6
# 1                                               11.9
# 2                                               20.5
# 3                                               28.9
# 4                                               22.5
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years - Related children of the householder under 18 years - Related children of the householder 5 to 17 years  \
# 0                                                7.5
# 1                                                7.3
# 2                                               13.2
# 3                                               24.6
# 4                                               11.9
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over  \
# 0                                                8.8
# 1                                               11.9
# 2                                               10.2
# 3                                               14.5
# 4                                               10.1
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 18 to 64 years  \
# 0                                                8.4
# 1                                               13.7
# 2                                               11.2
# 3                                               16.3
# 4                                               11.0
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over  \
# 0                                                9.9
# 1                                                7.3
# 2                                                7.5
# 3                                               10.0
# 4                                                7.7
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - People in families  \
# 0                                                5.4
# 1                                                5.8
# 2                                                8.8
# 3                                               13.2
# 4                                                8.6
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - Unrelated individuals 15 years and over
# 0                                               25.6
# 1                                               30.8
# 2                                               22.3
# 3                                               30.3
# 4                                               19.8
#
# [5 rows x 187 columns]

# %%
#Print out all remaining columns to look at which ones might be useful for predictive model
#for column in counties_df:
#    print(column)

# %%
#List of columns from Census data to use for Regression
column_list = ['Geography',
              'Estimate; EMPLOYMENT STATUS - Population 16 years and over', 
               'Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Unemployed',
              'Percent; EMPLOYMENT STATUS - Population 16 years and over - Not in labor force',
              'Percent; EMPLOYMENT STATUS - Females 16 years and over',
              'Estimate; COMMUTING TO WORK - Mean travel time to work (minutes)',
              'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Per capita income (dollars)',
              'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for workers (dollars)',
              'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for male full-time, year-round workers (dollars)',
              'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for female full-time, year-round workers (dollars)',
              'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With private health insurance',
              'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With public coverage',
              'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - No health insurance coverage',
              'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people',
              'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over',
              'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years']

# %%
shorter_df = counties_df[column_list]

# %%
shorter_df['Geography'] = shorter_df['Geography'].str.replace(" County, Iowa", "")
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
shorter_df.head()
# Out:
#    Geography  Estimate; EMPLOYMENT STATUS - Population 16 years and over  \
# 0      Adair                                               5810
# 1      Adams                                               3087
# 2  Allamakee                                              11106
# 3  Appanoose                                              10061
# 4    Audubon                                               4710
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Unemployed  \
# 0                                                2.0
# 1                                                2.6
# 2                                                2.1
# 3                                                3.7
# 4                                                1.7
#
#    Percent; EMPLOYMENT STATUS - Population 16 years and over - Not in labor force  \
# 0                                               34.7
# 1                                               39.3
# 2                                               35.9
# 3                                               41.6
# 4                                               36.9
#
#    Percent; EMPLOYMENT STATUS - Females 16 years and over  \
# 0                                               2956
# 1                                               1584
# 2                                               5480
# 3                                               5184
# 4                                               2406
#
#    Estimate; COMMUTING TO WORK - Mean travel time to work (minutes)  \
# 0                                               22.3
# 1                                               19.6
# 2                                               24.3
# 3                                               19.6
# 4                                               19.2
#
#    Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Per capita income (dollars)  \
# 0                                              28861
# 1                                              27022
# 2                                              27377
# 3                                              25543
# 4                                              31523
#
#    Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for workers (dollars)  \
# 0                                              32169
# 1                                              29727
# 2                                              30458
# 3                                              28643
# 4                                              29331
#
#    Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for male full-time, year-round workers (dollars)  \
# 0                                              44421
# 1                                              42583
# 2                                              44464
# 3                                              41576
# 4                                              44400
#
#    Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for female full-time, year-round workers (dollars)  \
# 0                                              36288
# 1                                              30139
# 2                                              32808
# 3                                              30561
# 4                                              29323
#
#    Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With private health insurance  \
# 0                                               73.1
# 1                                               75.8
# 2                                               71.6
# 3                                               63.9
# 4                                               70.3
#
#    Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With public coverage  \
# 0                                               38.7
# 1                                               38.8
# 2                                               37.6
# 3                                               45.3
# 4                                               42.7
#
#    Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - No health insurance coverage  \
# 0                                                6.4
# 1                                                5.8
# 2                                                8.6
# 3                                                8.4
# 4                                                6.6
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people  \
# 0                                                9.5
# 1                                               11.2
# 2                                               11.4
# 3                                               17.1
# 4                                               11.1
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over  \
# 0                                                9.9
# 1                                                7.3
# 2                                                7.5
# 3                                               10.0
# 4                                                7.7
#
#    Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years
# 0                                               12.1
# 1                                                8.6
# 2                                               15.3
# 3                                               26.3
# 4                                               15.3

# %%
shorter_df.columns
# Out:
# Index(['Geography',
#        'Estimate; EMPLOYMENT STATUS - Population 16 years and over',
#        'Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Unemployed',
#        'Percent; EMPLOYMENT STATUS - Population 16 years and over - Not in labor force',
#        'Percent; EMPLOYMENT STATUS - Females 16 years and over',
#        'Estimate; COMMUTING TO WORK - Mean travel time to work (minutes)',
#        'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Per capita income (dollars)',
#        'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for workers (dollars)',
#        'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for male full-time, year-round workers (dollars)',
#        'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for female full-time, year-round workers (dollars)',
#        'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With private health insurance',
#        'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With public coverage',
#        'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - No health insurance coverage',
#        'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people',
#        'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over',
#        'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years'],
#       dtype='object')

# %% [markdown]
# I will now edit all the remaining column names below to make them much more readable and understandable

# %%
shorter_df = shorter_df.rename(columns = {"Geography":"County", "Estimate; EMPLOYMENT STATUS - Population 16 years and over":"Popul_16_Over",
                                          'Percent; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Unemployed':'Unemployment_Rate',
                                          'Percent; EMPLOYMENT STATUS - Population 16 years and over - Not in labor force':'Not_in_Labor_Force_Pct',
                                          'Percent; EMPLOYMENT STATUS - Females 16 years and over':'Female_Popul_16_Over', 
                                          'Estimate; COMMUTING TO WORK - Mean travel time to work (minutes)':'Avg_Commute_Minutes',
                                          'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Per capita income (dollars)':'Per_capita_income',
                                          'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for workers (dollars)':'Median_Income',
                                          'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for male full-time, year-round workers (dollars)':'Median_Male_Income',
                                          'Estimate; INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Median earnings for female full-time, year-round workers (dollars)':'Median_Female_Income',
                                          'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With private health insurance': 'Priv_Health_Ins_Pct',
                                          'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - With health insurance coverage - With public coverage':'Pub_Health_Ins_Pct',
                                          'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - No health insurance coverage':'No_Health_Ins_Pct',
                                          'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people':'Poverty_Rate_Total',
                                          'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - 18 years and over - 65 years and over':'Poverty_Rate_Over_65',
                                          'Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people - Under 18 years':'Poverty_Rate_Children'})

# %%
shorter_df.head()
shorter_df['County'] = shorter_df['County'].str.replace(" ", "")
shorter_df['County'] = shorter_df['County'].str.replace("'", "")

# %%
county_census_df = pd.merge(county_rating_area_df, shorter_df, 'left', ['County'])
county_census_df.head(3)
# Out:
#      Rating_Area   County  Popul_16_Over  Unemployment_Rate  \
# 0  Rating Area 1  Calhoun           7933                1.3
# 1  Rating Area 1  Carroll          15879                1.7
# 2  Rating Area 1   Greene           7300                4.1
#
#    Not_in_Labor_Force_Pct  Female_Popul_16_Over  Avg_Commute_Minutes  \
# 0                    43.4                  3854                 20.4
# 1                    31.4                  8172                 14.0
# 2                    34.2                  3788                 19.6
#
#    Per_capita_income  Median_Income  Median_Male_Income  Median_Female_Income  \
# 0              27370          26657               44283                 30671
# 1              29191          32365               46455                 36187
# 2              27968          29346               44864                 36695
#
#    Priv_Health_Ins_Pct  Pub_Health_Ins_Pct  No_Health_Ins_Pct  \
# 0                 76.3                40.5                3.6
# 1                 80.7                33.4                2.5
# 2                 74.7                38.8                5.3
#
#    Poverty_Rate_Total  Poverty_Rate_Over_65  Poverty_Rate_Children
# 0                15.3                   9.1                   21.3
# 1                10.3                   8.7                   12.8
# 2                10.0                   6.3                   11.7

# %%
#Merging healthcare plan dataframe with census dataframe
combined_df = pd.merge(county_census_df, insurance_df, 'left', ['Rating_Area'])

# %%
combined_df.head()
# Out:
#      Rating_Area   County  Popul_16_Over  Unemployment_Rate  \
# 0  Rating Area 1  Calhoun           7933                1.3
# 1  Rating Area 1  Calhoun           7933                1.3
# 2  Rating Area 1  Calhoun           7933                1.3
# 3  Rating Area 1  Calhoun           7933                1.3
# 4  Rating Area 1  Calhoun           7933                1.3
#
#    Not_in_Labor_Force_Pct  Female_Popul_16_Over  Avg_Commute_Minutes  \
# 0                    43.4                  3854                 20.4
# 1                    43.4                  3854                 20.4
# 2                    43.4                  3854                 20.4
# 3                    43.4                  3854                 20.4
# 4                    43.4                  3854                 20.4
#
#    Per_capita_income  Median_Income  Median_Male_Income  ...  \
# 0              27370          26657               44283  ...
# 1              27370          26657               44283  ...
# 2              27370          26657               44283  ...
# 3              27370          26657               44283  ...
# 4              27370          26657               44283  ...
#
#    Poverty_Rate_Total  Poverty_Rate_Over_65  Poverty_Rate_Children  \
# 0                15.3                   9.1                   21.3
# 1                15.3                   9.1                   21.3
# 2                15.3                   9.1                   21.3
# 3                15.3                   9.1                   21.3
# 4                15.3                   9.1                   21.3
#
#        Insurance_Company  Age  Metal_Level  Marketplace Non_Tobacco_Premium  \
# 0  Freedom Life Ins. Co.   60       Bronze          Off              844.53
# 1  Freedom Life Ins. Co.   42       Bronze          Off              412.31
# 2  Freedom Life Ins. Co.   28       Bronze          Off              338.25
# 3  Freedom Life Ins. Co.   20       Bronze          Off              197.60
# 4  Freedom Life Ins. Co.   47       Bronze          Off              486.37
#
#    Tobacco_Premium                                           Counties
# 0          1013.44  Boone, Calhoun, Carroll, Greene, Grundy, Hamil...
# 1           494.77  Boone, Calhoun, Carroll, Greene, Grundy, Hamil...
# 2           405.90  Boone, Calhoun, Carroll, Greene, Grundy, Hamil...
# 3           237.12  Boone, Calhoun, Carroll, Greene, Grundy, Hamil...
# 4           583.64  Boone, Calhoun, Carroll, Greene, Grundy, Hamil...
#
# [5 rows x 24 columns]

# %%
combined_df['Rating_Area'] = combined_df['Rating_Area'].str.replace("Rating Area ", "")
combined_df = combined_df.drop(columns=['Counties'])

# %%
combined_df.head()
# Out:
#   Rating_Area   County  Popul_16_Over  Unemployment_Rate  \
# 0           1  Calhoun           7933                1.3
# 1           1  Calhoun           7933                1.3
# 2           1  Calhoun           7933                1.3
# 3           1  Calhoun           7933                1.3
# 4           1  Calhoun           7933                1.3
#
#    Not_in_Labor_Force_Pct  Female_Popul_16_Over  Avg_Commute_Minutes  \
# 0                    43.4                  3854                 20.4
# 1                    43.4                  3854                 20.4
# 2                    43.4                  3854                 20.4
# 3                    43.4                  3854                 20.4
# 4                    43.4                  3854                 20.4
#
#    Per_capita_income  Median_Income  Median_Male_Income  ...  \
# 0              27370          26657               44283  ...
# 1              27370          26657               44283  ...
# 2              27370          26657               44283  ...
# 3              27370          26657               44283  ...
# 4              27370          26657               44283  ...
#
#    No_Health_Ins_Pct  Poverty_Rate_Total  Poverty_Rate_Over_65  \
# 0                3.6                15.3                   9.1
# 1                3.6                15.3                   9.1
# 2                3.6                15.3                   9.1
# 3                3.6                15.3                   9.1
# 4                3.6                15.3                   9.1
#
#    Poverty_Rate_Children      Insurance_Company  Age  Metal_Level Marketplace  \
# 0                   21.3  Freedom Life Ins. Co.   60       Bronze         Off
# 1                   21.3  Freedom Life Ins. Co.   42       Bronze         Off
# 2                   21.3  Freedom Life Ins. Co.   28       Bronze         Off
# 3                   21.3  Freedom Life Ins. Co.   20       Bronze         Off
# 4                   21.3  Freedom Life Ins. Co.   47       Bronze         Off
#
#    Non_Tobacco_Premium Tobacco_Premium
# 0               844.53         1013.44
# 1               412.31          494.77
# 2               338.25          405.90
# 3               197.60          237.12
# 4               486.37          583.64
#
# [5 rows x 23 columns]

# %%
#Convert categorical variables into dummy variables so we can use them in model
combined_df = pd.get_dummies(combined_df, columns=['Rating_Area', 'Marketplace', 'Metal_Level', 'Insurance_Company'], drop_first=True)
combined_df.columns
# Out:
# Index(['County', 'Popul_16_Over', 'Unemployment_Rate',
#        'Not_in_Labor_Force_Pct', 'Female_Popul_16_Over', 'Avg_Commute_Minutes',
#        'Per_capita_income', 'Median_Income', 'Median_Male_Income',
#        'Median_Female_Income', 'Priv_Health_Ins_Pct', 'Pub_Health_Ins_Pct',
#        'No_Health_Ins_Pct', 'Poverty_Rate_Total', 'Poverty_Rate_Over_65',
#        'Poverty_Rate_Children', 'Age', 'Non_Tobacco_Premium',
#        'Tobacco_Premium', 'Rating_Area_2', 'Rating_Area_3', 'Rating_Area_4',
#        'Rating_Area_5', 'Rating_Area_6', 'Rating_Area_7', 'Marketplace_On',
#        'Metal_Level_Catastrophic', 'Metal_Level_Gold', 'Metal_Level_Platinum',
#        'Metal_Level_Silver', 'Insurance_Company_Freedom Life Ins. Co.',
#        'Insurance_Company_Gundersen Health Plan, Inc.',
#        'Insurance_Company_Medica Insurance Company',
#        'Insurance_Company_Wellmark Health Plan of Iowa',
#        'Insurance_Company_Wellmark Synergy Health, Inc.',
#        'Insurance_Company_Wellmark Value Health Plan, Inc.',
#        'Insurance_Company_Wellmark, Inc.'],
#       dtype='object')

# %%
#make dummy variables more readable
combined_df = combined_df.rename(columns = {"Insurance_Company_Freedom Life Ins. Co.":"Freedom_Life_Ins_Co", "Insurance_Company_Gundersen Health Plan, Inc.":"Gundersen_Ins_Co",
                                          'Insurance_Company_Medica Insurance Company':'Medica_Ins_Co',
                                          'Insurance_Company_Wellmark Health Plan of Iowa':'Wellmark_Health_Plan_Iowa_Ins_Co',
                                          'Insurance_Company_Wellmark Synergy Health, Inc.':'Wellmark_Synergy_Health_Ins_Co', 
                                          'Insurance_Company_Wellmark Value Health Plan, Inc.':'Wellmark_Value_Health_Plan_Ins_Co',
                                          'Insurance_Company_Wellmark, Inc.':'Wellmark_Ins_Co'})

# %%
combined_df.head(2)
# Out:
#     County  Popul_16_Over  Unemployment_Rate  Not_in_Labor_Force_Pct  \
# 0  Calhoun           7933                1.3                    43.4
# 1  Calhoun           7933                1.3                    43.4
#
#    Female_Popul_16_Over  Avg_Commute_Minutes  Per_capita_income  \
# 0                  3854                 20.4              27370
# 1                  3854                 20.4              27370
#
#    Median_Income  Median_Male_Income  Median_Female_Income  ...  \
# 0          26657               44283                 30671  ...
# 1          26657               44283                 30671  ...
#
#    Metal_Level_Gold  Metal_Level_Platinum  Metal_Level_Silver  \
# 0                 0                     0                   0
# 1                 0                     0                   0
#
#    Freedom_Life_Ins_Co  Gundersen_Ins_Co  Medica_Ins_Co  \
# 0                    1                 0              0
# 1                    1                 0              0
#
#    Wellmark_Health_Plan_Iowa_Ins_Co  Wellmark_Synergy_Health_Ins_Co  \
# 0                                 0                               0
# 1                                 0                               0
#
#    Wellmark_Value_Health_Plan_Ins_Co  Wellmark_Ins_Co
# 0                                  0                0
# 1                                  0                0
#
# [2 rows x 37 columns]

# %%
combined_df.columns
# Out:
# Index(['County', 'Popul_16_Over', 'Unemployment_Rate',
#        'Not_in_Labor_Force_Pct', 'Female_Popul_16_Over', 'Avg_Commute_Minutes',
#        'Per_capita_income', 'Median_Income', 'Median_Male_Income',
#        'Median_Female_Income', 'Priv_Health_Ins_Pct', 'Pub_Health_Ins_Pct',
#        'No_Health_Ins_Pct', 'Poverty_Rate_Total', 'Poverty_Rate_Over_65',
#        'Poverty_Rate_Children', 'Age', 'Non_Tobacco_Premium',
#        'Tobacco_Premium', 'Rating_Area_2', 'Rating_Area_3', 'Rating_Area_4',
#        'Rating_Area_5', 'Rating_Area_6', 'Rating_Area_7', 'Marketplace_On',
#        'Metal_Level_Catastrophic', 'Metal_Level_Gold', 'Metal_Level_Platinum',
#        'Metal_Level_Silver', 'Freedom_Life_Ins_Co', 'Gundersen_Ins_Co',
#        'Medica_Ins_Co', 'Wellmark_Health_Plan_Iowa_Ins_Co',
#        'Wellmark_Synergy_Health_Ins_Co', 'Wellmark_Value_Health_Plan_Ins_Co',
#        'Wellmark_Ins_Co'],
#       dtype='object')

# %%
#Save final dataframe to be used for regression models
combined_df.to_csv('combined_df.csv')
